# %% [markdown]
# # Ictonyx Quickstart
#
# The standard practice in machine learning is to train a model once and report the result as a fixed quantity. This is statistically unsound: a model's performance is a random variable, and a single observation is an inadequate description of its distribution.
#
# Ictonyx trains a model N times under independent random seeds, collects the resulting metric distributions, and applies appropriate statistical tests to compare them. This notebook demonstrates the complete workflow on a three-class wine classification task.
#
# **Requirements:** `pip install ictonyx tensorflow scikit-learn matplotlib`
#
# **Parts:**
# 1. Characterise the variability of a single model
# 2. Test whether two models genuinely differ
# 3. Compare three models with multiple-comparison correction

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
import warnings
warnings.filterwarnings('ignore')

# Uncomment if running in Google Colab:
# !pip install 'ictonyx[tensorflow]' scikit-learn -q

# %%
import tensorflow as tf
import numpy as np
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
import ictonyx as ix

print(f'Ictonyx v{ix.__version__}')
print(f'TensorFlow v{tf.__version__}')
# Out:
# Ictonyx v0.4.6
# TensorFlow v2.21.0

# %% [markdown]
# ## The dataset
#
# The wine dataset: 178 samples, 13 chemical measurements, 3 cultivar classes. Small enough
# to train in seconds; hard enough that weight initialisation matters. We standardise the
# features — gradient-based methods are sensitive to feature scale, and the resulting
# variability should reflect genuine initialisation sensitivity, not conditioning artefacts.

# %%
data = load_wine()
X = StandardScaler().fit_transform(data.data).astype(np.float32)
y = data.target

print(f'{len(X)} samples  |  {X.shape[1]} features  |  {len(np.unique(y))} classes')
print(f'Classes: {list(data.target_names)}')
# Out:
# 178 samples  |  13 features  |  3 classes
# Classes: [np.str_('class_0'), np.str_('class_1'), np.str_('class_2')]

# %% [markdown]
# ## Part 1 — Characterising the variability of a single model
#
# A small feed-forward network is sensitive to weight initialisation: the loss landscape
# is non-convex, the gradient descent trajectory depends on where it starts, and different
# starting points can converge to solutions with meaningfully different generalisation
# performance.
#
# We pass a model builder function to `variability_study()`. Ictonyx calls it once per
# run, constructing a fresh model each time with a different random seed injected through
# the config.

# %%
def build_model(config):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(16, activation='relu', input_shape=(13,)),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(3,  activation='softmax'),
    ])
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy'],
    )
    return ix.KerasModelWrapper(model)


results = ix.variability_study(
    model=build_model,
    data=(X, y),
    runs=20,
    epochs=20,
    seed=42,
    verbose=False,
)

print(results.summarize())
# Out:
# Variability Study Results
# ...
# Successful runs: 0
# Seed: 42
#
# Note: no held-out test data — validation metrics shown. Provide test data via DataHandler for unbiased evaluation.

# %% [markdown]
# The SD and min/max range quantify the seed-dependent component of performance — the part
# that a conventional single-run evaluation discards entirely. The same architecture on the
# same data, varying only in random initialisation, can land anywhere across that range.
# Without a distribution, there is no way to know where your reported figure falls within it.

# %%
# The full distribution is available for any downstream use
val_accs = results.get_metric_values('val_accuracy')
for i, acc in enumerate(val_accs, 1):
    print(f'  Run {i:2d}: {acc:.4f}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # The full distribution is available for any downstream use
# ----> 2 val_accs = results.get_metric_values('val_accuracy')
#       3 for i, acc in enumerate(val_accs, 1):
#       4     print(f'  Run {i:2d}: {acc:.4f}')
#
# File ~/projects/ictonyx/ictonyx/runners.py:983, in VariabilityStudyResults.get_metric_values(self, metric_name)
#     981 if metric_name not in self.final_metrics:
#     982     available = sorted(self.final_metrics.keys())
# --> 983     raise KeyError(f"Metric '{metric_name}' not found. Available: {available}")
#     984 return self.final_metrics[metric_name]
#
# KeyError: "Metric 'val_accuracy' not found. Available: []"

# %% [markdown]
# ## Part 2 — Visualising the distribution
#
# The left panel shows all 20 training curves overlaid with a mean line. The right panel
# shows the distribution of final-epoch validation accuracy across runs. The spread in the
# right panel is the quantity of scientific interest.

# %%
ix.plot_variability_summary(results=results, metric='accuracy', show=False);

# %% [markdown]
# ## Part 3 — Testing whether two models genuinely differ
#
# The question of whether one model outperforms another is routinely answered by comparing
# two single-run numbers. The correct formulation is a hypothesis test over the two outcome
# distributions.
#
# For two models, `compare_models()` uses the paired Wilcoxon signed-rank test by default.
# Both models receive identical per-run seeds — runs are genuinely paired at the RNG level
# — so pairing removes noise common to both models and makes the test more powerful than
# an unpaired alternative.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier

comparison = ix.compare_models(
    models=[
        MLPClassifier(hidden_layer_sizes=(64,), max_iter=200),
        RandomForestClassifier(n_estimators=40),
    ],
    data=(X, y),
    runs=20,
    metric='val_accuracy',
    seed=42,
    verbose=False,
)

print(comparison.get_summary())

# %% [markdown]
# The p-value addresses statistical significance; the effect size (rank-biserial correlation
# r) addresses practical significance — how consistent is the advantage across runs?
# r = 1.0 means one model won every single paired run; r = 0.0 means the results were
# evenly split.
#
# The `none correction` label indicates that with only two models there is a single pair
# to test, so no multiple-comparison correction is needed.

# %%
ix.plot_comparison_boxplots(comparison, show=False);

# %% [markdown]
# ## Part 4 — Three models with multiple-comparison correction
#
# When comparing three or more models, the familywise error rate compounds. Running three
# independent pairwise tests at α = 0.05 yields a false positive probability of roughly
# 0.14 — nearly three times the nominal rate. Ictonyx controls for this with a two-stage
# procedure: a Kruskal-Wallis omnibus test first, pairwise comparisons only if the omnibus
# rejects, and Holm step-down correction applied to the pairwise p-values.
#
# A non-significant result is a result: it means the data do not support a conclusion, and
# the library correctly declines to draw one.

# %%
from sklearn.linear_model import LogisticRegression

three_way = ix.compare_models(
    models=[
        MLPClassifier(hidden_layer_sizes=(64,), max_iter=200),
        RandomForestClassifier(n_estimators=40),
        LogisticRegression(max_iter=1000),
    ],
    data=(X, y),
    runs=20,
    metric='val_accuracy',
    seed=42,
    verbose=False,
)

print(three_way.get_summary())

# %% [markdown]
# ## Part 5 — Forest plot
#
# A forest plot shows each model's mean difference from a designated baseline with a
# 95% confidence interval. A CI lying entirely to the right of zero indicates a model
# that outperforms the baseline. One that crosses zero is not distinguishable from the
# baseline by this test.

# %%
ix.plot_comparison_forest(
    comparison_results=three_way,
    baseline_model='LogisticRegression',
    metric='Accuracy',
    show=False,
);

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook ran 60 independent training runs across three models, characterised their
# metric distributions, applied an omnibus test with Holm-corrected post-hoc comparisons,
# and produced a forest plot — without any manual configuration of the statistical
# procedure. The choice of test, the correction method, and the bootstrap confidence
# intervals were all determined automatically from the data.
#
# For deeper examples — Keras CNN variability studies, PyTorch workflows, learning rate sweeps,
# and multi-model sklearn comparisons — see the other notebooks in examples/.
