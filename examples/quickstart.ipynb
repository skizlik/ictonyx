# %% [markdown]
# # Ictonyx Quickstart
#
# The standard practice in applied machine learning is to train a model once and report the resulting metric as a fixed quantity. This is statistically unsound: a model's performance is a random variable, and a single observation is an inadequate description of its distribution.
#
# Ictonyx addresses this by training a model N times under independent random seeds, collecting the resulting metric distributions, and applying appropriate statistical tests to compare them. This notebook demonstrates the complete workflow using only scikit-learn — no GPU required — on a ten-class handwritten digit recognition task.
#
# **Requirements:** `pip install ictonyx scikit-learn matplotlib`

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'      # suppress TF C++ logs
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'     # suppress oneDNN message
import warnings
warnings.filterwarnings('ignore')

# %%
# Uncomment if running in Google Colab
# !pip install ictonyx scikit-learn matplotlib

import ictonyx as ix
print(f"Ictonyx v{ix.__version__}")
# Out:
# Ictonyx v0.3.10

# %% [markdown]
# ## The dataset
#
# The MNIST digits dataset: 1,797 samples, 64 features (8×8 pixel intensity values), 10 classes. It is a well-characterised multi-class benchmark with a non-trivial prediction task. We standardise the features before passing them to Ictonyx — gradient-based methods are sensitive to feature scale, and the resulting variability should reflect genuine initialisation sensitivity rather than the artefact of poorly conditioned inputs.

# %%
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
import numpy as np

digits = load_digits()
X = StandardScaler().fit_transform(digits.data).astype(np.float32)
y = digits.target

print(f"{len(X)} samples, {X.shape[1]} features, {len(np.unique(y))} classes")
# Out:
# 1797 samples, 64 features, 10 classes

# %% [markdown]
# ## Part 1 — Characterising the variability of a single model
#
# A two-layer MLP is sensitive to weight initialisation in a way that a Random Forest is not: the loss landscape is non-convex, the gradient descent trajectory depends on where it starts, and different starting points can converge to solutions with meaningfully different generalisation performance.
#
# We pass a configured `MLPClassifier` instance to `variability_study()`. Ictonyx uses `sklearn.base.clone()` to construct a fresh, unfitted copy for each run — preserving the specified hyperparameters while ensuring runs are independent.

# %%
from sklearn.neural_network import MLPClassifier

results = ix.variability_study(
    model=MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300),
    data=(X, y),
    runs=20,
    seed=42,
)

print(results.summarize())
# Out:
# Cloning MLPClassifier instance per run for independence.
# Loading and preparing data...
# Array splits - Train: 1257, Val: 180, Test: 360
# Data loaded successfully
#
# Starting Variability Study
#   Runs: 20
#   Epochs per run: 10
#   Execution mode: in standard mode
#   Seed: 42
# Variability Study: 100%|██| 20/20 [00:47<00:00,  2.38s/run, val_accuracy=0.9833]
# --------------------------------------------------
#
# Study Summary:
#   Successful runs: 20/20
#   train_accuracy: 1.0000 (SD = 0.0000)
#   val_accuracy: 0.9833 (SD = 0.0046)
# Variability Study Results
# ...
# Successful runs: 20
# Seed: 42
# train_accuracy:
#   Mean: 1.0000
#   Std:  0.0000
#   Min:  1.0000
#   Max:  1.0000
# val_accuracy:
#   Mean: 0.9833
#   Std:  0.0046
#   Min:  0.9722
#   Max:  0.9889

# %% [markdown]
# The standard deviation and the min/max range quantify the seed-dependent component of performance — the part that a conventional single-run evaluation discards entirely. An MLP achieving 0.9722 on one seed and 0.9889 on another is the same architecture on the same data; the difference is purely attributable to initialisation. Without a distribution, there is no way to know which end of that range your reported figure comes from.

# %%
# The full distribution is available for any downstream use
val_accs = results.get_metric_values('val_accuracy')

for i, acc in enumerate(val_accs, 1):
    print(f"  Run {i:2d}: {acc:.4f}")
# Out:
#   Run  1: 0.9889
#   Run  2: 0.9778
#   Run  3: 0.9833
#   Run  4: 0.9778
#   Run  5: 0.9889
#   Run  6: 0.9833
#   Run  7: 0.9833
#   Run  8: 0.9722
#   Run  9: 0.9833
#   Run 10: 0.9889
#   Run 11: 0.9889
#   Run 12: 0.9778
#   Run 13: 0.9833
#   Run 14: 0.9833
#   Run 15: 0.9778
#   Run 16: 0.9833
#   Run 17: 0.9889
#   Run 18: 0.9889
#   Run 19: 0.9833
#   Run 20: 0.9833

# %% [markdown]
# ## Part 2 — Visualising the distribution

# %%
ix.plot_variability_summary(
    all_runs_metrics_list=results.all_runs_metrics,
    final_metrics_series=results.final_metrics['val_accuracy'],
    metric='accuracy',
)

# %% [markdown]
# The left panel shows all 20 training curves overlaid; the right panel shows the distribution of final-epoch validation accuracy. The spread in the right panel is the quantity of scientific interest. A model with tight distribution is insensitive to initialisation and its point estimate is reproducible. One with a wide distribution is not — and which of the two you have is only knowable from the distribution, not from any single run.
#
# ## Part 3 — Testing whether two models differ
#
# The question of whether one model outperforms another is routinely answered by comparing two point estimates. The correct formulation is a hypothesis test over the two outcome distributions. Without distributions, the comparison conflates genuine performance differences with random seed effects — and with only 1,797 samples, those effects are non-negligible.
#
# `compare_models()` runs a complete variability study for each model and selects the appropriate two-sample test automatically: it tests for normality via Shapiro-Wilk, for variance homogeneity via Levene's test, and routes to Student's t, Welch's t, or Mann-Whitney U accordingly. Effect sizes and bootstrap confidence intervals are computed regardless of which path is taken.

# %%
from sklearn.ensemble import RandomForestClassifier

comparison = ix.compare_models(
    models=[
        MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300),
        RandomForestClassifier(),
    ],
    data=(X, y),
    runs=20,
    metric='val_accuracy',
    seed=42,
)

print(comparison.get_summary())
# Out:
# --- Starting Comparison of 2 Models (seed=42) ---
# Evaluating: MLPClassifier
# Cloning MLPClassifier instance per run for independence.
# Loading and preparing data...
# Array splits - Train: 1257, Val: 180, Test: 360
# Data loaded successfully
#
# Starting Variability Study
#   Runs: 20
#   Epochs per run: 10
#   Execution mode: in standard mode
#   Seed: 42
# Variability Study: 100%|██| 20/20 [00:48<00:00,  2.42s/run, val_accuracy=0.9833]
# --------------------------------------------------
#
# Study Summary:
#   Successful runs: 20/20
#   train_accuracy: 1.0000 (SD = 0.0000)
#   val_accuracy: 0.9833 (SD = 0.0046)
# Evaluating: RandomForestClassifier
# Cloning RandomForestClassifier instance per run for independence.
# Loading and preparing data...
# Array splits - Train: 1257, Val: 180, Test: 360
# Data loaded successfully
#
# Starting Variability Study
#   Runs: 20
#   Epochs per run: 10
#   Execution mode: in standard mode
#   Seed: 42
# ...

# %% [markdown]
# The result provides three quantities for the comparison. The p-value addresses statistical significance: is the observed difference larger than would be expected by chance under the null hypothesis of equal distributions? The effect size (rank-biserial correlation for the non-parametric path) addresses practical significance: how large is the difference in terms of the overlap between the two distributions? The bootstrap confidence interval gives a plausible range for the true mean difference.
#
# These three quantities answer different questions. It is possible to have a small, statistically significant effect (large n, tight distributions) or a large effect that does not reach significance (small n, high variability). Reporting only the p-value obscures which situation you are in.

# %%
# The underlying distributions are directly accessible
for name, series in comparison.raw_data.items():
    print(f"{name}:")
    print(f"  Mean: {series.mean():.4f}  SD: {series.std():.4f}  n={len(series)}")
# Out:
# MLPClassifier:
#   Mean: 0.9833  SD: 0.0048  n=20
# RandomForestClassifier:
#   Mean: 0.9886  SD: 0.0073  n=20

# %% [markdown]
# ## Part 4 — Three-model comparison with multiple comparison correction
#
# When comparing three or more models, the familywise error rate compounds. Running three independent pairwise tests at α = 0.05 yields a familywise false positive probability of approximately 0.14 — nearly three times the nominal rate. Ictonyx controls for this with a two-stage procedure: a Kruskal-Wallis omnibus test is run first, and pairwise comparisons are conducted only if the omnibus null is rejected. Holm step-down correction is then applied to the pairwise p-values.

# %%
from sklearn.linear_model import LogisticRegression

three_way = ix.compare_models(
    models=[
        MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300),
        RandomForestClassifier(),
        LogisticRegression(max_iter=1000),
    ],
    data=(X, y),
    runs=20,
    metric='val_accuracy',
    seed=42,
)

print(three_way.get_summary())
# Out:
# --- Starting Comparison of 3 Models (seed=42) ---
# Evaluating: MLPClassifier
# Cloning MLPClassifier instance per run for independence.
# Loading and preparing data...
# Array splits - Train: 1257, Val: 180, Test: 360
# Data loaded successfully
#
# Starting Variability Study
#   Runs: 20
#   Epochs per run: 10
#   Execution mode: in standard mode
#   Seed: 42
# Variability Study: 100%|██| 20/20 [00:48<00:00,  2.43s/run, val_accuracy=0.9833]
# --------------------------------------------------
#
# Study Summary:
#   Successful runs: 20/20
#   train_accuracy: 1.0000 (SD = 0.0000)
#   val_accuracy: 0.9833 (SD = 0.0046)
# Evaluating: RandomForestClassifier
# Cloning RandomForestClassifier instance per run for independence.
# Loading and preparing data...
# Array splits - Train: 1257, Val: 180, Test: 360
# Data loaded successfully
#
# Starting Variability Study
#   Runs: 20
#   Epochs per run: 10
#   Execution mode: in standard mode
#   Seed: 42
# ...

# %% [markdown]
# ## Part 5 — Forest plot
#
# A forest plot displays each model's mean difference from a designated baseline alongside its confidence interval. It is the conventional visualisation for comparative studies that report effect sizes — the interval width encodes both the magnitude of the difference and the precision with which it is estimated.

# %%
ix.plot_comparison_forest(
    comparison_results=three_way,
    baseline_model='LogisticRegression',
    metric='Accuracy',
)

# %% [markdown]
# The vertical dashed line marks zero — no difference from the baseline. A confidence interval lying entirely to the right of zero indicates a model that outperforms the baseline at the nominal level. One that crosses zero is not distinguishable from the baseline by this test.
#
# ---
#
# ## Summary
#
# Starting from a standardised array, this notebook ran 60 independent training runs across three models, characterised their metric distributions, applied an omnibus test with post-hoc correction under Holm's procedure, and produced a forest plot — without any manual configuration of the statistical procedure. The decisions about which test to apply, whether to correct for multiple comparisons, and how to compute the bootstrap confidence intervals were all made automatically based on the properties of the data.
#
# For Keras, PyTorch, learning rate sweeps, and grid studies, see the other notebooks in `examples/`.
